# %% [markdown]
# ### TASK 3

# %% [markdown]
# ### Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
task = pd.read_csv("Task 3.csv")
task.head(80)
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0    30   unemployed   married    primary      no     1787      no   no
# 1    33     services   married  secondary      no     4789     yes  yes
# 2    35   management    single   tertiary      no     1350     yes   no
# 3    30   management   married   tertiary      no     1476     yes  yes
# 4    59  blue-collar   married  secondary      no        0     yes   no
# ..  ...          ...       ...        ...     ...      ...     ...  ...
# 75   54   management  divorced   tertiary      no     3222      no   no
# 76   41  blue-collar  divorced  secondary      no      174     yes   no
# 77   40   technician    single  secondary      no      591      no  yes
# 78   50  blue-collar  divorced    primary      no      388      no   no
# 79   40   unemployed   married  secondary      no      219     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
task.shape
# Out:
# (4521, 17)

# %%
task.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
task.info
# Out:
# <bound method DataFrame.info of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
task.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
task.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Visualizing numerical columns using histogram

# %%
task_obj = task.select_dtypes(include='object').columns
task_num = task.select_dtypes(exclude='object').columns
for feature in task_num:
    sns.histplot(x=feature,data=task,bins=25,kde=True,color='red')
    plt.show()

# %%
for feature in task_obj:
    plt.figure(figsize=(8,3))
    plt.title(f'count plot of{feature}')
    sns.countplot(x=feature,data=task,palette='viridis')
    plt.xticks(rotation=40)
    plt.show()
# Out:
# C:\Users\marri\AppData\Local\Temp\ipykernel_17920\532786267.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature,data=task,palette='viridis')
# C:\Users\marri\AppData\Local\Temp\ipykernel_17920\532786267.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature,data=task,palette='viridis')
# C:\Users\marri\AppData\Local\Temp\ipykernel_17920\532786267.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature,data=task,palette='viridis')
# ...

# %%
counts = task['marital'].value_counts()
plt.figure(figsize=(8,4))
plt.pie(counts,labels=counts.index,autopct='%1.1f%%',startangle=90)
plt.title('Distribution of marital status')
plt.axis('equal')
plt.show()
